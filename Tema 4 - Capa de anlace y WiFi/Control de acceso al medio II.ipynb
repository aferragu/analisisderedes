# %% [markdown]
# # Curso Análisis de Redes
#
# ## Cátedra Teoría de las Telecomunicaciones - Universidad ORT Uruguay
#
#
#
# # Mecanismos de control de acceso al medio (MAC), 2a. Parte

# %%
#using Pkg;Pkg.instantiate(); Pkg.update()

# %% [markdown]
# ## Carrier Sense Multiple Access
#
# La principal ineficiencia de ALOHA es que los slots son de un tamaño entero de paquete, y si quedan vacíos no se utilizan. La razón es que las estaciones *no pueden saber si el medio está en uso o no*.
#
# **Idea:** escuchar el medio antes de acceder. Solo acceder si el mismo está libre.
#
# Esto permite que se separe el largo del slot *de contención* (donde se compite) del tamaño de transmisión, ya que si alguien accede al medio puede usarlo un tiempo largo sin ser interrumpido. El tiempo no puede ser demasiado largo para permitir rotación entre las estaciones.
#
# Esto lleva al mecanismo **CSMA**.

# %% [markdown]
# ### Protocolo CSMA
#
# Consideremos el siguiente protocolo:
#
# > **Protocolo CSMA ($p$-persistente)**:
# >
# > * Cada estación transmite paquetes de largo $L=1$ durante tiempo $T=1$.
# >
# > * Todas las estaciones escuchan el medio. Cuando este queda libre un tiempo "corto" $\beta<1$:
# >
# >      * Se divide el tiempo en slots de tamaño $\beta$.
# >      * Cada estación intenta acceder en un slot con probabilidad $p$ de forma independiente.
# >
# > * Si una única estación accede en un slot, gana el acceso sin interrupciones.
# >
# > * Si dos o más estaciones acceden *en el mismo slot* se produce una colisión, que dura lo mismo que la transmisión.

# %% [markdown]
# ### Análisis por ciclos de CSMA
#
# Existen 3 tipos de ciclo en este sistema, que se representan en el siguiente diagrama
#
# ![Ciclos CSMA](../images/csma_ciclos.png)

# %% [markdown]
# ### Análisis por ciclos de CSMA
#
# Separemos el tiempo en ciclos. Sea $L$ la cantidad de paquetes transmitidos con éxito en un ciclo y $T$ la duración del ciclo, entonces:
#
# **Casos:**
#
#  * Slot Idle: si nadie transmite. Probabilidad $P(X=0) = (1-p)^N$.
#  * Éxito: si transmite uno solo. Probabilidad $P(X=1) = Np(1-p)^{N-1}$.
#  * Colisión: en otro caso.
#
# **Tabla de ciclos**:
#
# | Caso  | Prob.  | $L$ | $T$  |
# |---|:-----------:|---|---|
# | Idle | $$(1-p)^N$$  | $0$  | $\beta$  |
# | Exito | $Np(1-p)^{N-1}$  | $1$ | $1+\beta$ |
# | Colision | $1-(1-p)^N-Np(1-p)^{N-1}$  | $0$  | $1+\beta$  |

# %% [markdown]
# ### Throughput de saturación de CSMA
#
# De la tabla anterior concluimos que:
#
# $$\bar{L} = Np(1-p)^{N-1}, \quad \bar{T} = \beta + 1-(1-p)^N$$
#
# De donde el *throughput* de CSMA se calcula como:
#
# $$Thr = \frac{\bar{L}}{\bar{T}} = \frac{Np(1-p)^{N-1}}{\beta + 1-(1-p)^N}$$

# %% [markdown]
# ### Ejemplo

# %%
using Plots, LaTeXStrings; default(size=(900,400), legendfontsize=10)

function csma_throughput(p,N,beta)
   return N*p*(1-p)^(N-1)/(beta+1-(1-p)^N) 
end
# Out:
# csma_throughput (generic function with 1 method)

# %%
beta=.1
p=0:0.001:1
NN=[1,2,5,10,15,20]
plt=plot()
for N in NN
    plot!(p,csma_throughput.(p,N,beta),xlabel=L"p", ylabel=L"Thr",label=L"N=%$N")
end
plt

# %% [markdown]
# ### Probabilidad óptima de acceso
#
# Lamentablemente, en este caso no existe una expresión para la probabilidad óptima de acceso. Se puede calcular numéricamente.

# %%
function max_throughput_csma(N,beta)
    p=(0:0.001:1)
    Thr = csma_throughput.(p,N,beta)
    Thropt,i = findmax(Thr)
    return Thropt,p[i]
end

beta=0.01
NN=1:20
out = max_throughput_csma.(NN,beta)
Thr = [x[1] for x in out]
p = [x[2] for x in out]

plot(NN,Thr, lt=:stem, marker=:circle, label=L"Thr^*", xlabel=L"N")

# %%
plot(NN,p, lt=:stem, marker=:circle, label=L"p^*", xlabel=L"N")

# %% [markdown]
# ### Comportamiento asintótico
#
# Para $N$ grande y $\beta \ll 1$, vale la siguiente aproximación:
#
# > **Throughput CSMA**
# >
# > $$p^* \approx \frac{\sqrt{2\beta}}{N} \quad Thr^* \approx \frac{1}{1+\sqrt{2\beta}}.$$

# %%
p1=plot(NN,p, lt=:stem, marker=:circle, label=L"p^*", xlabel=L"N")
plot!(p1,NN,sqrt(2*beta)./NN, label=L"\sqrt{2\beta}/N")
p2=plot(NN,Thr, lt=:stem, marker=:circle, label=L"Thr^*", xlabel=L"N", legend=:bottomright)
plot!(p2,NN,1 ./(1 .+sqrt(2*beta))*ones(size(NN)), label=L"1/(1+\sqrt{2\beta})")
plt=plot(p1,p2)

# %% [markdown]
# ### Simulación

# %%
using Distributions

function simula_csma(p,N,beta,Tfinal)
    
    t = 0.0 
    T = Float64[]
    X = String[];
    
    d=Binomial(N,p)
    
    while t<Tfinal

        push!(T,t)

        aux = rand(d) #no. de estaciones que intentan acceder
        if aux == 0
            push!(X,"Idle")
            t = t+beta
        elseif aux == 1
            push!(X,"Exito")
            t = t+1+beta
        else
            push!(X,"Colision")
            t = t+1+beta
        end
    
    end
    
    return T,X
end
# Out:
# simula_csma (generic function with 1 method)

# %%
N=10
p=0.05
beta=0.1
Tfinal=10

T,X = simula_csma(p,N,beta,Tfinal)
println(T)
println(X)
# Out:
# [0.0, 0.1, 0.2, 1.3, 2.4, 2.5, 2.6, 3.7, 3.8000000000000003, 4.9, 6.0, 6.1, 6.199999999999999, 6.299999999999999, 7.399999999999999, 7.499999999999998, 8.599999999999998, 8.699999999999998, 8.799999999999997, 9.899999999999997, 9.999999999999996]
# ["Idle", "Idle", "Exito", "Exito", "Idle", "Idle", "Exito", "Idle", "Exito", "Exito", "Idle", "Idle", "Idle", "Colision", "Idle", "Exito", "Idle", "Idle", "Exito", "Idle", "Idle"]

# %%
plot(T,X.=="Idle",lt=:steppost, fill=(0,:blue), color=:blue, fillalpha=0.5, label="Idle", ylim=(0,2))
plot!(T,X.=="Exito",lt=:steppost, fill=(0,:teal), color=:green, fillalpha=0.5, label="Exito")
plot!(T,X.=="Colision",lt=:steppost, fill=(0,:red), color=:red, fillalpha=0.5, label="Colision")
plot!(T,ones(size(T)), lt=:stem, color=:black, label=:none)

# %%
##Calculamos el tiempo acumulado que efectivamente pasamos en cada estado.
acumI=cumsum((X[1:end-1].=="Idle").*diff(T))
acumE=cumsum((X[1:end-1].=="Exito").*diff(T))
acumC=cumsum((X[1:end-1].=="Colision").*diff(T))

plot(T[2:end],acumI, color=:blue, label="Idle",legend=:topleft, title="Tiempo acumulado en cada estado")
plot!(T[2:end],acumE, color=:teal, label="Exito")
plot!(T[2:end],acumC, color=:red, label="Colision")

# %%
N=10
p=0.05
beta=0.1
Tfinal=1000

T,X = simula_csma(p,N,beta,Tfinal);

acumI=cumsum((X[1:end-1].=="Idle").*diff(T))
acumE=cumsum((X[1:end-1].=="Exito").*diff(T))
acumC=cumsum((X[1:end-1].=="Colision").*diff(T))

plot(T[2:end],acumI, color=:blue, label="Idle", legend=:topleft, title="Tiempo acumulado en cada estado")
plot!(T[2:end],acumE, color=:teal, label="Exito")
plot!(T[2:end],acumC, color=:red, label="Colision")

# %%
plot(T,cumsum(X.=="Exito"), color=:blue, label=:none, legend=:topleft, title="Paquetes enviados vs. tiempo")

# %% [markdown]
# ### Throughput de simulación

# %%
## Cantidad de paquetes enviados:
Ltot = sum(X.=="Exito")
Ttot = T[end]
Thr_empirico = Ltot/Ttot

println("Throughput de simulacion: ",Thr_empirico)
println("Throughput teorico: ",csma_throughput(p,N,beta))
println()
println("L medio: ",mean(X.=="Exito"))
println("L medio teórico: ",N*p*(1-p)^(N-1))
println()
println("T medio: ",mean(diff(T)))
println("T medio teórico: ",beta+1-(1-p)^N)
# Out:
# Throughput de simulacion: 0.6380638063806178
# Throughput teorico: 0.6286613347959504
#
# L medio: 0.3127450980392157
# L medio teórico: 0.31512470486230454
#
# T medio: 0.4903874448259106
# T medio teórico: 0.5012630607616214

# %% [markdown]
# ## Carrier Sense Multiple Access - Collision Detection
#
# La principal ineficiencia remanente es que los tiempos de colisión siguen siendo comparables al tiempo de transmisión.
#
# **Idea:** Agregar a CSMA la posibilidad de detectar una colisión y abortar la transmisión.
#
# Esto permite que los tiempos de colisión sean cortos, nuevamente comparables al tiempo de propagación en el medio, es decir, se acercan al tamaño de slot. Este mecanismo es el de Ethernet clásico, ya que se puede escuchar el medio mientras se transmite y comparar con lo que se está enviando.
#
# Esto lleva al mecanismo **CSMA/CD**.

# %% [markdown]
# ### Protocolo CSMA/CD
#
# Consideremos el siguiente protocolo:
#
# > **Protocolo CSMA/CD ($p$-persistente)**:
# >
# > * Cada estación transmite paquetes de largo $L=1$ durante tiempo $T=1$.
# >
# > * Todas las estaciones escuchan el medio. Cuando este queda libre un tiempo "corto" $\beta<1$:
# >
# >      * Se divide el tiempo en slots de tamaño $\beta$.
# >      * Cada estación intenta acceder en un slot con probabilidad $p$ de forma independiente.
# >
# > * Si una única estación accede en un slot, gana el acceso sin interrupciones.
# >
# > * Si dos o más estaciones acceden *en el mismo slot* se produce una colisión. Las estaciones la detectan y abortan la transmisión al cabo de un tiempo $\beta$.

# %% [markdown]
# ### Análisis por ciclos de CSMA/CD
#
# Existen 3 tipos de ciclo en este sistema, que se representan en el siguiente diagrama
#
# ![Ciclos CSMA](../images/csmacd_ciclos.png)

# %% [markdown]
# ### Análisis por ciclos de CSMA/CD
#
# Separemos el tiempo en ciclos. Sea $L$ la cantidad de paquetes transmitidos con éxito en un ciclo y $T$ la duración del ciclo, entonces:
#
# **Casos:**
#
#  * Slot Idle: si nadie transmite. Probabilidad $P(X=0) = (1-p)^N$.
#  * Éxito: si transmite uno solo. Probabilidad $P(X=1) = Np(1-p)^{N-1}$.
#  * Colisión: en otro caso.
#
# **Tabla de ciclos**:
#
# | Caso  | Prob.  | $L$ | $T$  |
# |---|:-----------:|---|:---:|
# | Idle | $$(1-p)^N$$  | $0$  | $\beta$  |
# | Exito | $Np(1-p)^{N-1}$  | $1$ | $1+\beta$ |
# | Colision | $1-(1-p)^N-Np(1-p)^{N-1}$  | $0$  | $\beta$  |

# %% [markdown]
# ### Throughput de saturación de CSMA/CD
#
# De la tabla anterior concluimos que:
#
# $$\bar{L} = Np(1-p)^{N-1}, \quad \bar{T} = \beta + Np(1-p)^N$$
#
# De donde el *throughput* de CSMA/CD se calcula como:
#
# $$Thr = \frac{\bar{L}}{\bar{T}} = \frac{Np(1-p)^{N-1}}{\beta + Np(1-p)^{N-1}} = \frac{1}{1+\frac{\beta}{Np(1-p)^{N-1}}}$$

# %% [markdown]
# ### Ejemplo

# %%
using Plots, LaTeXStrings; default(size=(1000,400), legendfontsize=11)

function csmacd_throughput(p,N,beta)
   return N*p*(1-p)^(N-1)/(beta+N*p*(1-p)^(N-1)) 
end
# Out:
# csmacd_throughput (generic function with 1 method)

# %%
beta=0.1
p=0:0.001:1
NN=[1,2,5,10,15,20]
plt=plot()
for N in NN
    plot!(p,csmacd_throughput.(p,N,beta),xlabel=L"p", ylabel=L"Thr",label=L"N=%$N")
end
plt

# %% [markdown]
# ### Probabilidad óptima de acceso
#
# En este caso puede volver a calcularse la probabilidad óptima de acceso. Basta observar que para maximizar el Throughput, hay que minimizar el denominador, y esto corresponde a maximizar:
#
# $$Np(1-p)^{N-1}.$$
#
# Es decir, maximizar la probabilidad de éxito, al igual que en ALOHA. Por lo tanto:
#
# $$p^* = \frac{1}{N} \quad Thr^* = \frac{1}{1+\frac{\beta}{(1-1/N)^{N-1}}}$$
#
# **Observaciones:**
#
#  * La probabilidad de acceso se vuelve *independiente* del tamaño de slot, solo depende de la congestión.
#
#  * Para $N\to\infty$, el Throughput óptimo verifica:
#
#  $$Thr^* \approx \frac{1}{1+e\beta} \approx \frac{1}{1+2.78\beta}.$$
#
#  Nuevamente, cuanto más pequeño $\beta$ más eficiente el sistema.

# %%
function max_throughput_csmacd(N,beta)
    return 1/(1+beta/(1-1/N)^(N-1))
end

beta=0.1
NN=1:20

plot(NN,max_throughput_csmacd.(NN,beta), lt=:stem, marker=:circle, label=L"Thr^*", xlabel=L"N",legend=:bottomright)
plot!(NN,1/(1+exp(1)*beta)*ones(size(NN)), label=L"1/(1+e\beta)")

# %% [markdown]
# ### Simulación

# %%
using Distributions

function simula_csmacd(p,N,beta,Tfinal)
    
    t = 0.0 
    T = Float64[]
    X = String[];
    k=1
    
    d=Binomial(N,p)
    
    while t<Tfinal

        push!(T,t)

        aux = rand(d)
        if aux == 0
            push!(X,"Idle")
            t = t+beta
        elseif aux==1
            push!(X,"Exito")
            t = t+1+beta
        else
            push!(X,"Colision")
            t = t+beta
        end
    
        
    end
    
    return T,X
end
# Out:
# simula_csmacd (generic function with 1 method)

# %%
N=10
p=0.1
beta=0.1
Tfinal=10

T,X = simula_csmacd(p,N,beta,Tfinal)
# Out:
# ([0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 1.5, 2.6, 2.7, 3.8000000000000003, 3.9000000000000004  …  9.099999999999996, 9.199999999999996, 9.299999999999995, 9.399999999999995, 9.499999999999995, 9.599999999999994, 9.699999999999994, 9.799999999999994, 9.899999999999993, 9.999999999999993], ["Idle", "Colision", "Idle", "Idle", "Exito", "Exito", "Idle", "Exito", "Idle", "Colision"  …  "Idle", "Colision", "Colision", "Idle", "Colision", "Idle", "Idle", "Colision", "Idle", "Exito"])

# %%
plot(T,X.=="Idle",lt=:steppost, fill=(0,:blue), color=:blue, fillalpha=0.5, label="Idle", ylim=(0,2))
plot!(T,X.=="Exito",lt=:steppost, fill=(0,:teal), color=:green, fillalpha=0.5, label="Exito")
plot!(T,X.=="Colision",lt=:steppost, fill=(0,:red), color=:red, fillalpha=0.5, label="Colision")
plot!(T,ones(size(T)), lt=:stem, color=:black, label=:none)

# %%
##Calculamos el tiempo acumulado que efectivamente pasamos en cada estado.
acumI=cumsum((X[1:end-1].=="Idle").*diff(T))
acumE=cumsum((X[1:end-1].=="Exito").*diff(T))
acumC=cumsum((X[1:end-1].=="Colision").*diff(T))

plot(T[2:end],acumI, color=:blue, label="Idle", legend=:topleft, title="Tiempo acumulado en cada estado")
plot!(T[2:end],acumE, color=:teal, label="Exito")
plot!(T[2:end],acumC, color=:red, label="Colision")

# %%
N=10
p=0.1
beta=0.1
Tfinal=1000

T,X = simula_csmacd(p,N,beta,Tfinal);

acumI=cumsum((X[1:end-1].=="Idle").*diff(T))
acumE=cumsum((X[1:end-1].=="Exito").*diff(T))
acumC=cumsum((X[1:end-1].=="Colision").*diff(T))

plot(T[2:end],acumI, color=:blue, label="Idle", legend=:topleft, title="Tiempo acumulado en cada estado")
plot!(T[2:end],acumE, color=:teal, label="Exito")
plot!(T[2:end],acumC, color=:red, label="Colision")

# %%
plot(T,cumsum(X.=="Exito"), color=:blue, label=:none, legend=:topleft, title="Paquetes enviados vs. tiempo")

# %% [markdown]
# ### Throughput de simulación

# %%
## Cantidad de paquetes enviados:
Ltot = sum(X.=="Exito")
Ttot = T[end]
Thr_empirico = Ltot/Ttot

println("Throughput de simulacion: ",Thr_empirico)
println("Throughput teorico: ",csmacd_throughput(p,N,beta))
println()
println("L medio: ",mean(X.=="Exito"))
println("L medio teórico: ",N*p*(1-p)^(N-1))
println()
println("T medio: ",mean(diff(T)))
println("T medio teórico: ",beta+N*p*(1-p)^(N-1))
# Out:
# Throughput de simulacion: 0.7917917917917656
# Throughput teorico: 0.7948383331091361
#
# L medio: 0.3782879005260641
# L medio teórico: 0.3874204890000001
#
# T medio: 0.47799043062202534
# T medio teórico: 0.4874204890000001

# %% [markdown]
# ## Ethernet y el Exponential Backoff
#
# Las redes Ethernet clásicas trabajan con paquetes de largo $L=1500$ bytes y utilizan CSMA/CD, siendo el tiempo de slot $\sigma = 51.2\mu s$ y la velocidad de transmisión $10Mbps$.
#
# A su vez, el mecanismo de acceso no es exactamente el visto para CSMA/CD, sino que utilizan *Binary Exponential Backoff*:
#
# > **Binary exponential backoff:**
# >
# > * Cada estación mantiene una ventana mínima de backoff $W=W_0$ (slots).
# >
# > * Al intentar transmitir un paquete, se sortea uniforme un contador entre $0$ y $W_0-1$. Se espera esta cantidad de slots antes de transmitir (es decir se va decrementando el contador).
# >
# > * Al llegar a $0$ transmite. Si hay colisión (se detecta mediante una señal de jam de mínimo 32 bits), la próxima vez se duplica $W$ y se sortea en un intervalo más largo (hasta un máximo $W$ posible).
# >
# > * Si se transmite con éxito, se vuelve a $W=W_0$.
#
# En el caso de Ethernet, se toma $W_0=2$ (se transmite practicamente enseguida).

# %% [markdown]
# ## El caso de WiFi (IEEE 802.11)
#
# El algoritmo de acceso al medio en WiFi se inspira fuertemente en el algoritmo de Ethernet. El principal problema es la *imposibilidad de detectar colisiones*. Luego veremos un modelo detallado del mismo (en particular de los tiempos de transmisión y overhead involucrados).
#
# Se definen dos modos de funcionamiento:
#
#  * DCF (Distributed Coordination Function) basic access, análogo a CSMA.
#  * DCF + RTS/CTS (DCF con Request-to-send/Clear-to-send), también conocido como CSMA/CA.

# %% [markdown]
# ### El algoritmo RTS/CTS para estaciones inalámbricas
#
# **Idea:** replicar el mecanismo de detección de colisiones en el medio inalámbrico.
#
# > **Algoritmo RTS/CTS (Request to send/Clear to send):**
# >
# > * Cada estación intenta acceder al medio de la misma manera que en CSMA o Ethernet.
# >
# > * Al intentar acceder, transmite un paquete de tipo RTS (request to send) indicando *cuánto tiempo hará uso del medio*.
# >
# > * El destino (típicamente el AP) contesta con un paquete tipo CTS (clear to send) aprobando la transmisión.
# >
# > * Si se recibe correctamente el intercambio RTS/CTS, se comienza inmediatamente la transmisión del paquete.

# %% [markdown]
# ### RTS/CTS, ventajas y desventajas
#
# **Ventajas:**
#
# * Las colisiones se reducen a colisionar sobre el RTS/CTS (por ejemplo, dos RTS al mismo tiempo, no hay CTS). Si el tiempo de estos paquetes es mucho menor que el tiempo de transmisión, replicamos la situación de CSMA/CD (colisiones cortas).
#
# * El uso de RTS/CTS provoca que *todas* las estaciones de la celda estén informadas de la transmisión, solucionando el llamado "problema de la estación oculta", cuando quien colisiona conmigo está fuera de mi alcance de radio.
#
#
# **Desventajas:**
#
# * A baja carga, se introduce el overhead adicional de tener que enviar el RTS/CTS, que se agrega el tiempo de transmisión.
#
# * Los RTS/CTS deben ser entendidos por todas las estaciones, por lo que en general se envían a un bitrate más bajo que el paquete. Esto provoca ineficiencias que exploraremos en el siguiente ejercicio.

# %% [markdown]
# ## Ejercicio: un primer modelo de WiFi
#
# Consideremos la norma WiFi IEEE 802.11. En un principio esta norma trabajaba únicamente a $1Mbps$, pero en la revisión $802.11b$ se llevó hasta $11Mbps$. El tamaño de slot se fijó en $20\mu s$, y el tamaño típico de paquete es de $1500$ bytes ($12000$ bits). A su vez, la ventana mínima del Binary exponential backoff es $W_0=32$. Se permitía habilitar el RTS/CTS.
#
# En una primera aproximación podemos modelar este sistema como un CSMA con o sin RTS/CTS. Los tiempos involucrados son:
#
# * Tiempo de espera a medio libre (DIFS): $50\mu s$.
# * Tiempo de transmisión de un paquete: $T_{datos} + T_{PHY} + T_{MAC} + T_{ack}$ siendo:
#     * $T_{PHY} = 192 \mu s$
#     * $T_{MAC} = 160 $bits (transmitidos a la misma velocidad que los datos).
#     * $T_{ack} = T_{PHY} + 10 \mu s + 14 bytes$ (transmitidos a la misma velocidad que los datos).
#
# * Para el caso de RTS/CTS:
#     * $T_{RTS} = T_{PHY} + 10 \mu s + 20 bytes = 362 \mu s$ (los bytes van transmitidos a 1Mbps).
#     * $T_{CTS} = T_{PHY} + 10 \mu s + 14 bytes = 314 \mu s$ (los bytes van transmitidos a 1Mbps).
#
# * Como $W_0=32$, podemos aproximar en primera instancia la probabilidad de acceso por $p=1/16$ (se accede 1 de cada 16 slots en promedio).
#
# Realizar los análisis por ciclos de este sistema para $N$ estaciones, con la probabilidad $p$ supuesta antes y los tiempos involucrados, suponiendo:
#
#    1. Capa física de $1Mbps$, acceso básico.
#    2. Capa física de $1Mbps$, acceso RTS/CTS.
#    3. Capa física de $11Mbps$, acceso básico.
#    4. Capa física de $11Mbps$, acceso RTS/CTS.
#
# Graficar el throughput que se puede lograr en función de la cantidad de estaciones para cada caso.
